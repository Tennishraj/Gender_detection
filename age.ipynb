# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
import glob

# %%
# initial parameters
epochs = 100
lr = 1e-3
batch_size = 64
img_dims = (96,96,3)

data = []
labels = []

# %%
import glob
import os
import random

# Load image files from the dataset
image_files = [f for f in glob.glob(r'D:/my-files/20-50/20-50/Gender-Detection-master/Gender-Detection-master/gender_dataset_face' + "/**/*", recursive=True) if not os.path.isdir(f)]
random.shuffle(image_files)

# %%
# converting images to arrays and labelling the categories
for img in image_files:

    image = cv2.imread(img)
    
    image = cv2.resize(image, (img_dims[0],img_dims[1]))
    image = img_to_array(image)
    data.append(image)

    label = img.split(os.path.sep)[-2] # C:\Files\gender_dataset_face\woman\face_1162.jpg
    if label == "woman":
        label = 1
                                                                                  
    else:
        label = 0
        
    labels.append([label]) # [[1], [0], [0],...]

# %%
# Pre-processing with float32
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Split dataset for training and validation
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2, random_state=42)

# Check unique labels
print("Unique train labels:", np.unique(trainY))
print("Unique test labels:", np.unique(testY))

# Find the number of classes based on the unique labels
num_classes = np.max(trainY) + 1  # Ensure that num_classes matches your label range

# Convert labels to categorical
trainY = to_categorical(trainY, num_classes=num_classes)
testY = to_categorical(testY, num_classes=num_classes)

# Verify shape of trainY and testY
print("TrainY shape:", trainY.shape)
print("TestY shape:", testY.shape)
# Out:
# Unique train labels: [0 1]
# Unique test labels: [0 1]
# TrainY shape: (1845, 2)
# TestY shape: (462, 2)

# %%
# augmenting datset 
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# %%
# define model
def build(width, height, depth, classes):
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1

    if K.image_data_format() == "channels_first": #Returns a string, either 'channels_first' or 'channels_last'
        inputShape = (depth, height, width)
        chanDim = 1
    
    # The axis that should be normalized, after a Conv2D layer with data_format="channels_first", 
    # set axis=1 in BatchNormalization.

    model.add(Conv2D(32, (3,3), padding="same", input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3,3)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(classes))
    model.add(Activation("sigmoid"))

    return model

# %%
# build model
model = build(width=img_dims[0], height=img_dims[1], depth=img_dims[2],
                            classes=2)
# Out:
# C:\Users\Test\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from keras.optimizers import Adam

# Set learning rate and epochs
learning_rate = 0.001  # Replace with your desired learning rate
epochs = 500  # Replace with your number of epochs

# Compile the model
opt = Adam(learning_rate=learning_rate)  # Remove decay
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Example model for 30 classes
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(96, 96, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='softmax'))  # Change this to 30 classes

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
H = model.fit(
    aug.flow(trainX, trainY, batch_size=batch_size),
    validation_data=(testX, testY),
    steps_per_epoch=len(trainX) // batch_size,
    epochs=epochs,
    verbose=1
)
# Out:
# Epoch 1/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.6007 - loss: 1.9475 - val_accuracy: 0.7771 - val_loss: 0.4895
# Epoch 2/500
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.7500 - loss: 0.4654
# c:\Users\Test\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7500 - loss: 0.4654 - val_accuracy: 0.7727 - val_loss: 0.4743
# Epoch 3/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.7345 - loss: 0.5173 - val_accuracy: 0.8052 - val_loss: 0.4412
# Epoch 4/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7547 - loss: 0.4528 - val_accuracy: 0.8268 - val_loss: 0.3908
# Epoch 5/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 263ms/step - accuracy: 0.8202 - loss: 0.4068 - val_accuracy: 0.8377 - val_loss: 0.3595
# Epoch 6/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8438 - loss: 0.4560 - val_accuracy: 0.8420 - val_loss: 0.3544
# Epoch 7/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.8074 - loss: 0.4301 - val_accuracy: 0.8658 - val_loss: 0.3122
# Epoch 8/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7969 - loss: 0.4927 - val_accuracy: 0.8528 - val_loss: 0.3248
# Epoch 9/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8224 - loss: 0.3894 - val_accuracy: 0.8463 - val_loss: 0.3231
# Epoch 10/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.3565 - val_accuracy: 0.8312 - val_loss: 0.3629
# Epoch 11/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.8354 - loss: 0.3761 - val_accuracy: 0.8550 - val_loss: 0.3135
# Epoch 12/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9219 - loss: 0.3239 - val_accuracy: 0.8701 - val_loss: 0.2902
# Epoch 13/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.8609 - loss: 0.3233 - val_accuracy: 0.7965 - val_loss: 0.4510
# Epoch 14/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7812 - loss: 0.5027 - val_accuracy: 0.8247 - val_loss: 0.3786
# Epoch 15/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.8395 - loss: 0.3643 - val_accuracy: 0.8701 - val_loss: 0.2824
# Epoch 16/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7969 - loss: 0.4396 - val_accuracy: 0.8745 - val_loss: 0.2718
# Epoch 17/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.8493 - loss: 0.3406 - val_accuracy: 0.8918 - val_loss: 0.2535
# Epoch 18/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.3026 - val_accuracy: 0.8810 - val_loss: 0.2831
# Epoch 19/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.8565 - loss: 0.3371 - val_accuracy: 0.9026 - val_loss: 0.2458
# Epoch 20/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9531 - loss: 0.1732 - val_accuracy: 0.8983 - val_loss: 0.2444
# Epoch 21/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.8418 - loss: 0.3363 - val_accuracy: 0.9004 - val_loss: 0.2703
# Epoch 22/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8281 - loss: 0.3115 - val_accuracy: 0.8636 - val_loss: 0.2907
# Epoch 23/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.8582 - loss: 0.3412 - val_accuracy: 0.8874 - val_loss: 0.2585
# Epoch 24/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8906 - loss: 0.3952 - val_accuracy: 0.8961 - val_loss: 0.2488
# Epoch 25/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 266ms/step - accuracy: 0.8900 - loss: 0.2776 - val_accuracy: 0.9134 - val_loss: 0.2306
# Epoch 26/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8750 - loss: 0.2652 - val_accuracy: 0.9069 - val_loss: 0.2313
# Epoch 27/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8759 - loss: 0.2997 - val_accuracy: 0.9026 - val_loss: 0.2433
# Epoch 28/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9375 - loss: 0.2236 - val_accuracy: 0.9004 - val_loss: 0.2454
# Epoch 29/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8626 - loss: 0.3303 - val_accuracy: 0.8874 - val_loss: 0.2566
# Epoch 30/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.3127 - val_accuracy: 0.8810 - val_loss: 0.2738
# Epoch 31/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.8887 - loss: 0.2908 - val_accuracy: 0.8615 - val_loss: 0.3127
# Epoch 32/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 0.2778 - val_accuracy: 0.8550 - val_loss: 0.3174
# Epoch 33/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8820 - loss: 0.2873 - val_accuracy: 0.8896 - val_loss: 0.2579
# Epoch 34/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9219 - loss: 0.2605 - val_accuracy: 0.8896 - val_loss: 0.2624
# Epoch 35/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8824 - loss: 0.2857 - val_accuracy: 0.9091 - val_loss: 0.2387
# Epoch 36/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8750 - loss: 0.2854 - val_accuracy: 0.8874 - val_loss: 0.2642
# Epoch 37/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.8841 - loss: 0.2753 - val_accuracy: 0.9091 - val_loss: 0.2273
# Epoch 38/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9062 - loss: 0.2240 - val_accuracy: 0.9091 - val_loss: 0.2266
# Epoch 39/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.8817 - loss: 0.2717 - val_accuracy: 0.9048 - val_loss: 0.2303
# Epoch 40/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.2953 - val_accuracy: 0.9091 - val_loss: 0.2260
# Epoch 41/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.8617 - loss: 0.3013 - val_accuracy: 0.9048 - val_loss: 0.2364
# Epoch 42/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8594 - loss: 0.3062 - val_accuracy: 0.9004 - val_loss: 0.2421
# Epoch 43/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.8618 - loss: 0.3177 - val_accuracy: 0.8874 - val_loss: 0.2699
# Epoch 44/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8594 - loss: 0.4016 - val_accuracy: 0.8939 - val_loss: 0.2529
# Epoch 45/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8630 - loss: 0.3150 - val_accuracy: 0.9177 - val_loss: 0.2226
# Epoch 46/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9062 - loss: 0.2198 - val_accuracy: 0.9069 - val_loss: 0.2281
# Epoch 47/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 272ms/step - accuracy: 0.9042 - loss: 0.2558 - val_accuracy: 0.9069 - val_loss: 0.2382
# Epoch 48/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8438 - loss: 0.3667 - val_accuracy: 0.9156 - val_loss: 0.2301
# Epoch 49/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.8970 - loss: 0.2611 - val_accuracy: 0.9091 - val_loss: 0.2345
# Epoch 50/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8594 - loss: 0.2899 - val_accuracy: 0.9069 - val_loss: 0.2223
# Epoch 51/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.8926 - loss: 0.2568 - val_accuracy: 0.9048 - val_loss: 0.2525
# Epoch 52/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9219 - loss: 0.1886 - val_accuracy: 0.9091 - val_loss: 0.2291
# Epoch 53/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.8775 - loss: 0.2825 - val_accuracy: 0.9069 - val_loss: 0.2267
# Epoch 54/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8906 - loss: 0.2703 - val_accuracy: 0.9113 - val_loss: 0.2230
# Epoch 55/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.8838 - loss: 0.2671 - val_accuracy: 0.9156 - val_loss: 0.2130
# Epoch 56/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8906 - loss: 0.3113 - val_accuracy: 0.9156 - val_loss: 0.2118
# Epoch 57/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.8777 - loss: 0.2667 - val_accuracy: 0.8983 - val_loss: 0.2421
# Epoch 58/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8750 - loss: 0.3361 - val_accuracy: 0.9221 - val_loss: 0.2164
# Epoch 59/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 263ms/step - accuracy: 0.8944 - loss: 0.2593 - val_accuracy: 0.8896 - val_loss: 0.2442
# Epoch 60/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9531 - loss: 0.1797 - val_accuracy: 0.8939 - val_loss: 0.2470
# Epoch 61/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 265ms/step - accuracy: 0.9022 - loss: 0.2500 - val_accuracy: 0.9048 - val_loss: 0.2228
# Epoch 62/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9062 - loss: 0.2315 - val_accuracy: 0.9026 - val_loss: 0.2192
# Epoch 63/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8914 - loss: 0.2778 - val_accuracy: 0.9134 - val_loss: 0.2101
# Epoch 64/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.3111 - val_accuracy: 0.9177 - val_loss: 0.2084
# Epoch 65/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.8908 - loss: 0.2409 - val_accuracy: 0.9069 - val_loss: 0.1932
# Epoch 66/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8125 - loss: 0.4024 - val_accuracy: 0.9156 - val_loss: 0.1900
# Epoch 67/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8964 - loss: 0.2524 - val_accuracy: 0.9199 - val_loss: 0.1990
# Epoch 68/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9375 - loss: 0.1727 - val_accuracy: 0.9242 - val_loss: 0.1980
# Epoch 69/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.8842 - loss: 0.2776 - val_accuracy: 0.9134 - val_loss: 0.2128
# Epoch 70/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 0.1945 - val_accuracy: 0.9177 - val_loss: 0.2023
# Epoch 71/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 267ms/step - accuracy: 0.8929 - loss: 0.2641 - val_accuracy: 0.9264 - val_loss: 0.1801
# Epoch 72/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.2637 - val_accuracy: 0.9177 - val_loss: 0.1822
# Epoch 73/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.8970 - loss: 0.2563 - val_accuracy: 0.9264 - val_loss: 0.1796
# Epoch 74/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.2371 - val_accuracy: 0.9264 - val_loss: 0.1810
# Epoch 75/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9052 - loss: 0.2194 - val_accuracy: 0.9199 - val_loss: 0.1945
# Epoch 76/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 0.2118 - val_accuracy: 0.9199 - val_loss: 0.2058
# Epoch 77/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 289ms/step - accuracy: 0.8914 - loss: 0.2279 - val_accuracy: 0.8983 - val_loss: 0.2104
# Epoch 78/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8281 - loss: 0.3798 - val_accuracy: 0.9177 - val_loss: 0.1929
# Epoch 79/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - accuracy: 0.8970 - loss: 0.2310 - val_accuracy: 0.9177 - val_loss: 0.1927
# Epoch 80/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9219 - loss: 0.2106 - val_accuracy: 0.9221 - val_loss: 0.1999
# Epoch 81/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.9068 - loss: 0.2380 - val_accuracy: 0.9004 - val_loss: 0.2340
# Epoch 82/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9531 - loss: 0.1448 - val_accuracy: 0.9177 - val_loss: 0.2143
# Epoch 83/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9141 - loss: 0.2430 - val_accuracy: 0.8896 - val_loss: 0.2696
# Epoch 84/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8906 - loss: 0.2684 - val_accuracy: 0.8615 - val_loss: 0.3099
# Epoch 85/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.8899 - loss: 0.2603 - val_accuracy: 0.9242 - val_loss: 0.1826
# Epoch 86/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8594 - loss: 0.2373 - val_accuracy: 0.9264 - val_loss: 0.1871
# Epoch 87/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.8987 - loss: 0.2394 - val_accuracy: 0.9307 - val_loss: 0.1925
# Epoch 88/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 0.2535 - val_accuracy: 0.9264 - val_loss: 0.2009
# Epoch 89/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - accuracy: 0.9149 - loss: 0.2245 - val_accuracy: 0.8961 - val_loss: 0.2344
# Epoch 90/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.2585 - val_accuracy: 0.8918 - val_loss: 0.2444
# Epoch 91/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.9118 - loss: 0.2113 - val_accuracy: 0.9307 - val_loss: 0.1942
# Epoch 92/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.2662 - val_accuracy: 0.9307 - val_loss: 0.1914
# Epoch 93/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.8944 - loss: 0.2533 - val_accuracy: 0.9286 - val_loss: 0.1859
# Epoch 94/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9219 - loss: 0.2209 - val_accuracy: 0.9351 - val_loss: 0.1815
# Epoch 95/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9042 - loss: 0.2209 - val_accuracy: 0.9242 - val_loss: 0.1918
# Epoch 96/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9375 - loss: 0.1751 - val_accuracy: 0.9242 - val_loss: 0.1961
# Epoch 97/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 273ms/step - accuracy: 0.9007 - loss: 0.2364 - val_accuracy: 0.9307 - val_loss: 0.1741
# Epoch 98/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8906 - loss: 0.2613 - val_accuracy: 0.9329 - val_loss: 0.1815
# Epoch 99/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.9096 - loss: 0.2099 - val_accuracy: 0.9329 - val_loss: 0.1877
# Epoch 100/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8438 - loss: 0.3122 - val_accuracy: 0.9307 - val_loss: 0.1904
# Epoch 101/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9141 - loss: 0.2197 - val_accuracy: 0.8745 - val_loss: 0.2848
# Epoch 102/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9219 - loss: 0.2314 - val_accuracy: 0.8896 - val_loss: 0.2397
# Epoch 103/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.9168 - loss: 0.2090 - val_accuracy: 0.9351 - val_loss: 0.1835
# Epoch 104/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8906 - loss: 0.3500 - val_accuracy: 0.9286 - val_loss: 0.1835
# Epoch 105/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9193 - loss: 0.1952 - val_accuracy: 0.9199 - val_loss: 0.1835
# Epoch 106/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.1501 - val_accuracy: 0.9307 - val_loss: 0.1758
# Epoch 107/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.9082 - loss: 0.2205 - val_accuracy: 0.9091 - val_loss: 0.2344
# Epoch 108/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 0.1981 - val_accuracy: 0.9026 - val_loss: 0.2481
# Epoch 109/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.9247 - loss: 0.1891 - val_accuracy: 0.9134 - val_loss: 0.1980
# Epoch 110/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9531 - loss: 0.1347 - val_accuracy: 0.9069 - val_loss: 0.2057
# Epoch 111/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.9131 - loss: 0.1936 - val_accuracy: 0.9069 - val_loss: 0.2237
# Epoch 112/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8868 - loss: 0.2859 - val_accuracy: 0.9069 - val_loss: 0.2295
# Epoch 113/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9194 - loss: 0.2143 - val_accuracy: 0.9394 - val_loss: 0.1754
# Epoch 114/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9375 - loss: 0.2006 - val_accuracy: 0.9351 - val_loss: 0.1734
# Epoch 115/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.9175 - loss: 0.2018 - val_accuracy: 0.9177 - val_loss: 0.1956
# Epoch 116/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8750 - loss: 0.2806 - val_accuracy: 0.9091 - val_loss: 0.2018
# Epoch 117/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 292ms/step - accuracy: 0.9149 - loss: 0.2163 - val_accuracy: 0.9091 - val_loss: 0.2166
# Epoch 118/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9219 - loss: 0.2193 - val_accuracy: 0.9199 - val_loss: 0.1852
# Epoch 119/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 286ms/step - accuracy: 0.9214 - loss: 0.2003 - val_accuracy: 0.9242 - val_loss: 0.1891
# Epoch 120/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8906 - loss: 0.2204 - val_accuracy: 0.9199 - val_loss: 0.1940
# Epoch 121/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9113 - loss: 0.2233 - val_accuracy: 0.9004 - val_loss: 0.2122
# Epoch 122/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9219 - loss: 0.1925 - val_accuracy: 0.8896 - val_loss: 0.2541
# Epoch 123/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.9183 - loss: 0.2038 - val_accuracy: 0.9199 - val_loss: 0.1930
# Epoch 124/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8868 - loss: 0.3264 - val_accuracy: 0.9134 - val_loss: 0.1913
# Epoch 125/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 303ms/step - accuracy: 0.9327 - loss: 0.1744 - val_accuracy: 0.9329 - val_loss: 0.1673
# Epoch 126/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9688 - loss: 0.1337 - val_accuracy: 0.9329 - val_loss: 0.1710
# Epoch 127/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 307ms/step - accuracy: 0.9171 - loss: 0.2108 - val_accuracy: 0.8896 - val_loss: 0.2495
# Epoch 128/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8906 - loss: 0.2555 - val_accuracy: 0.9091 - val_loss: 0.2128
# Epoch 129/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - accuracy: 0.9251 - loss: 0.1873 - val_accuracy: 0.9307 - val_loss: 0.1818
# Epoch 130/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9531 - loss: 0.1603 - val_accuracy: 0.9329 - val_loss: 0.1771
# Epoch 131/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.9325 - loss: 0.1852 - val_accuracy: 0.9286 - val_loss: 0.1958
# Epoch 132/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 0.1913 - val_accuracy: 0.9221 - val_loss: 0.2113
# Epoch 133/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 290ms/step - accuracy: 0.9229 - loss: 0.1926 - val_accuracy: 0.9199 - val_loss: 0.2023
# Epoch 134/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8906 - loss: 0.2902 - val_accuracy: 0.9221 - val_loss: 0.1931
# Epoch 135/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 303ms/step - accuracy: 0.9281 - loss: 0.1838 - val_accuracy: 0.9242 - val_loss: 0.1989
# Epoch 136/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9811 - loss: 0.0716 - val_accuracy: 0.9177 - val_loss: 0.2144
# Epoch 137/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 290ms/step - accuracy: 0.9261 - loss: 0.1950 - val_accuracy: 0.9199 - val_loss: 0.1821
# Epoch 138/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8906 - loss: 0.2040 - val_accuracy: 0.9199 - val_loss: 0.1808
# Epoch 139/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 306ms/step - accuracy: 0.9146 - loss: 0.1911 - val_accuracy: 0.9199 - val_loss: 0.1895
# Epoch 140/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9062 - loss: 0.2037 - val_accuracy: 0.9199 - val_loss: 0.1886
# Epoch 141/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 301ms/step - accuracy: 0.9307 - loss: 0.1690 - val_accuracy: 0.9242 - val_loss: 0.1883
# Epoch 142/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9062 - loss: 0.2015 - val_accuracy: 0.9307 - val_loss: 0.1857
# Epoch 143/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 289ms/step - accuracy: 0.9209 - loss: 0.1880 - val_accuracy: 0.9264 - val_loss: 0.1833
# Epoch 144/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9531 - loss: 0.1042 - val_accuracy: 0.9286 - val_loss: 0.1872
# Epoch 145/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 299ms/step - accuracy: 0.9281 - loss: 0.1824 - val_accuracy: 0.9069 - val_loss: 0.2288
# Epoch 146/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9688 - loss: 0.1248 - val_accuracy: 0.9221 - val_loss: 0.1952
# Epoch 147/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - accuracy: 0.9158 - loss: 0.2048 - val_accuracy: 0.9329 - val_loss: 0.1612
# Epoch 148/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9375 - loss: 0.1726 - val_accuracy: 0.9242 - val_loss: 0.1672
# Epoch 149/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - accuracy: 0.9334 - loss: 0.1637 - val_accuracy: 0.9048 - val_loss: 0.2539
# Epoch 150/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9375 - loss: 0.1418 - val_accuracy: 0.9004 - val_loss: 0.3032
# Epoch 151/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 286ms/step - accuracy: 0.9130 - loss: 0.2070 - val_accuracy: 0.9242 - val_loss: 0.1820
# Epoch 152/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9062 - loss: 0.1927 - val_accuracy: 0.9264 - val_loss: 0.1822
# Epoch 153/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.9320 - loss: 0.1875 - val_accuracy: 0.9264 - val_loss: 0.1782
# Epoch 154/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9375 - loss: 0.1234 - val_accuracy: 0.9351 - val_loss: 0.1789
# Epoch 155/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 272ms/step - accuracy: 0.9307 - loss: 0.1712 - val_accuracy: 0.9329 - val_loss: 0.1783
# Epoch 156/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8438 - loss: 0.5099 - val_accuracy: 0.9372 - val_loss: 0.1791
# Epoch 157/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 290ms/step - accuracy: 0.9336 - loss: 0.1573 - val_accuracy: 0.9264 - val_loss: 0.1749
# Epoch 158/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9688 - loss: 0.0989 - val_accuracy: 0.9286 - val_loss: 0.1741
# Epoch 159/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 303ms/step - accuracy: 0.9317 - loss: 0.1932 - val_accuracy: 0.9329 - val_loss: 0.1920
# Epoch 160/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9062 - loss: 0.3132 - val_accuracy: 0.9351 - val_loss: 0.1702
# Epoch 161/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.9116 - loss: 0.2085 - val_accuracy: 0.9351 - val_loss: 0.1638
# Epoch 162/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9219 - loss: 0.2173 - val_accuracy: 0.9372 - val_loss: 0.1623
# Epoch 163/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step - accuracy: 0.9269 - loss: 0.1967 - val_accuracy: 0.9199 - val_loss: 0.1835
# Epoch 164/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9531 - loss: 0.1598 - val_accuracy: 0.9264 - val_loss: 0.1865
# Epoch 165/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.9273 - loss: 0.1619 - val_accuracy: 0.9481 - val_loss: 0.1547
# Epoch 166/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9375 - loss: 0.1362 - val_accuracy: 0.9416 - val_loss: 0.1560
# Epoch 167/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 296ms/step - accuracy: 0.9396 - loss: 0.1752 - val_accuracy: 0.9351 - val_loss: 0.1729
# Epoch 168/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9219 - loss: 0.1562 - val_accuracy: 0.9394 - val_loss: 0.1533
# Epoch 169/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - accuracy: 0.9288 - loss: 0.1713 - val_accuracy: 0.9242 - val_loss: 0.1805
# Epoch 170/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9219 - loss: 0.1489 - val_accuracy: 0.9242 - val_loss: 0.1884
# Epoch 171/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 296ms/step - accuracy: 0.9314 - loss: 0.1713 - val_accuracy: 0.9351 - val_loss: 0.1740
# Epoch 172/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9375 - loss: 0.2746 - val_accuracy: 0.9286 - val_loss: 0.2013
# Epoch 173/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 292ms/step - accuracy: 0.9347 - loss: 0.1738 - val_accuracy: 0.8788 - val_loss: 0.2697
# Epoch 174/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8750 - loss: 0.2942 - val_accuracy: 0.9091 - val_loss: 0.2235
# Epoch 175/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9328 - loss: 0.1740 - val_accuracy: 0.9437 - val_loss: 0.1573
# Epoch 176/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9062 - loss: 0.2108 - val_accuracy: 0.9351 - val_loss: 0.1674
# Epoch 177/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 293ms/step - accuracy: 0.9441 - loss: 0.1478 - val_accuracy: 0.9329 - val_loss: 0.1643
# Epoch 178/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.1665 - val_accuracy: 0.9329 - val_loss: 0.1690
# Epoch 179/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 273ms/step - accuracy: 0.9337 - loss: 0.1642 - val_accuracy: 0.9286 - val_loss: 0.1848
# Epoch 180/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.3115 - val_accuracy: 0.9242 - val_loss: 0.1745
# Epoch 181/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9513 - loss: 0.1293

# %%
# save the model to disk
model.save('gender.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
